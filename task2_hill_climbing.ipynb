# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu30186-web/AIT-LAB-TASK/blob/main/task2_hill_climbing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
target=10
current=2
while current!=target:
  print("current state:",current)
  if current<target:
    current+=1
else:
      current-=1
print("goal reached:",current)
# Out:
# current state: 2
# current state: 3
# current state: 4
# current state: 5
# current state: 6
# current state: 7
# current state: 8
# current state: 9
# goal reached: 9

# %%
m = [[1,0,0],[0,0,0],[0,0,0]]

a,b = map(int,input("start:").split())

x,y = map(int,input("goal:").split())

path = [(a,b)]

while (a,b) != (x,y):

    if a < x:
        a += 1

    elif b < y:
        b += 1

    path.append((a,b))

    print("path:",path)
    print("cost:",len(path)-1)
# Out:
# start:0 0
# goal:1 2
# path: [(0, 0), (1, 0)]
# cost: 1
# path: [(0, 0), (1, 0), (1, 1)]
# cost: 2
# path: [(0, 0), (1, 0), (1, 1), (1, 2)]
# cost: 3
